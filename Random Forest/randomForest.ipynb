# %%
#importing the libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_excel('glass.xlsx',sheet_name='glass')

# %%
data
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
data.shape
# Out:
# (214, 10)

# %%
data.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'], dtype='object')

# %%
data.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
data['Type'].unique()
# Out:
# array([1, 2, 3, 5, 6, 7], dtype=int64)

# %%
#checking for null values
data.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
#there are no null values

# %%
#check for unique values
for i in data.columns:
    print(f"Unique values for column: {i}\n\n{data[i].unique()}\n")
# Out:
# Unique values for column: RI
#
# [1.52101 1.51761 1.51618 1.51766 1.51742 1.51596 1.51743 1.51756 1.51918
#  1.51755 1.51571 1.51763 1.51589 1.51748 1.51784 1.52196 1.51911 1.51735
#  1.5175  1.51966 1.51736 1.51751 1.5172  1.51764 1.51793 1.51721 1.51768
#  1.51747 1.51775 1.51753 1.51783 1.51567 1.51909 1.51797 1.52213 1.51779
#  1.5221  1.51786 1.519   1.51869 1.52667 1.52223 1.51898 1.5232  1.51926
#  1.51808 1.51837 1.51778 1.51769 1.51215 1.51824 1.51754 1.51905 1.51977
#  1.52172 1.52227 1.52099 1.52152 1.523   1.51574 1.51848 1.51593 1.51631
#  1.5159  1.51645 1.51627 1.51613 1.51592 1.51646 1.51594 1.51409 1.51625
#  1.51569 1.5164  1.51841 1.51605 1.51588 1.51629 1.5186  1.51689 1.51811
#  1.51655 1.5173  1.5182  1.52725 1.5241  1.52475 1.53125 1.53393 1.52222
#  1.51818 1.52664 1.52739 1.52777 1.51892 1.51847 1.51846 1.51829 1.51708
#  1.51673 1.51652 1.51844 1.51663 1.51687 1.51707 1.52177 1.51872 1.51667
# ...

# %%
#here no unique values

# %% [markdown]
# Data visualization

# %%
# Histograms for each feature
data.hist(bins=20, figsize=(18,15))
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(data.corr(), annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
#here Ri and Ca are correlated(0.81)

# %%
# Box plots to identify outliers
plt.figure(figsize=(13,8))
sns.boxplot(data=data)
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
#here because of less entries we dont remove outliers

# %%
#there are no categorical column to convert it into numerical

# %%
x = data.drop(columns='Type')
y = data['Type']

# %%
x
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [214 rows x 9 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    7
# 210    7
# 211    7
# 212    7
# 213    7
# Name: Type, Length: 214, dtype: int64

# %%
#Data Preprocessing
#scaling the data
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit(x)
x = scaler.transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print()
print(y_train.shape)
print(y_test.shape)
# Out:
# (171, 9)
# (43, 9)
#
# (171,)
# (43,)

# %%
#predicting using the Random_Forest_Classifier
from sklearn.ensemble import RandomForestClassifier

model_RandomForest = RandomForestClassifier(n_estimators=150, random_state=42,max_depth=10)

#fit the model 
model_RandomForest.fit(x_train,y_train)

y_pred = model_RandomForest.predict(x_test)
print(list(zip(y_test,y_pred)))
# Out:
# [(1, 1), (7, 7), (1, 1), (7, 7), (2, 2), (2, 2), (1, 1), (2, 2), (2, 2), (2, 1), (6, 6), (5, 2), (2, 2), (2, 2), (6, 6), (5, 5), (7, 7), (1, 1), (1, 1), (6, 6), (2, 2), (7, 7), (7, 7), (7, 7), (3, 3), (2, 2), (1, 1), (1, 1), (5, 2), (1, 1), (1, 1), (2, 2), (3, 3), (2, 2), (1, 1), (7, 7), (5, 5), (3, 1), (2, 1), (2, 2), (2, 1), (7, 7), (1, 1)]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

cfm=confusion_matrix(y_test,y_pred)
print(cfm)

print("Classification report:")
print(classification_report(y_test,y_pred))

accuracy_RF=accuracy_score(y_test,y_pred)
print("Accuracy: {:.2f}%".format(accuracy_RF * 100))
# Out:
# [[11  0  0  0  0  0]
#  [ 3 11  0  0  0  0]
#  [ 1  0  2  0  0  0]
#  [ 0  2  0  2  0  0]
#  [ 0  0  0  0  3  0]
#  [ 0  0  0  0  0  8]]
# Classification report:
#               precision    recall  f1-score   support
#
#            1       0.73      1.00      0.85        11
#            2       0.85      0.79      0.81        14
#            3       1.00      0.67      0.80         3
#            5       1.00      0.50      0.67         4
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         8
#
#     accuracy                           0.86        43
#    macro avg       0.93      0.83      0.85        43
# weighted avg       0.88      0.86      0.86        43
#
# Accuracy: 86.05%

# %% [markdown]
# Bagging

# %%
from sklearn.ensemble import BaggingClassifier

# Create a bagging classifier 
bagging_classifier = BaggingClassifier(base_estimator= RandomForestClassifier(),n_estimators=100, random_state=42)

# Train the bagging classifier
bagging_classifier.fit(x_train, y_train)

# Make prediction 
y_pred_bagg = bagging_classifier.predict(x_test)
# Out:
# c:\ProgramData\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

cfm=confusion_matrix(y_test,y_pred_bagg)
print(cfm)

print("Classification report:")
print(classification_report(y_test,y_pred_bagg))

accuracy_bagging=accuracy_score(y_test,y_pred_bagg)
print("Accuracy: {:.2f}%".format(accuracy_bagging * 100))
# Out:
# [[11  0  0  0  0  0]
#  [ 3 10  0  0  0  1]
#  [ 1  0  2  0  0  0]
#  [ 0  2  0  2  0  0]
#  [ 0  0  0  0  3  0]
#  [ 0  0  0  0  0  8]]
# Classification report:
#               precision    recall  f1-score   support
#
#            1       0.73      1.00      0.85        11
#            2       0.83      0.71      0.77        14
#            3       1.00      0.67      0.80         3
#            5       1.00      0.50      0.67         4
#            6       1.00      1.00      1.00         3
#            7       0.89      1.00      0.94         8
#
#     accuracy                           0.84        43
#    macro avg       0.91      0.81      0.84        43
# weighted avg       0.86      0.84      0.83        43
#
# Accuracy: 83.72%

# %% [markdown]
# Boosting

# %%
from sklearn.ensemble import AdaBoostClassifier

# Initialize the Boosting model
boosting_model = AdaBoostClassifier(base_estimator=RandomForestClassifier(),n_estimators=100, random_state=42)

# Train the model
boosting_model.fit(x_train, y_train)

# Make predictions
y_pred_boosting = boosting_model.predict(x_test)
# Out:
# c:\ProgramData\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

cfm=confusion_matrix(y_test,y_pred_boosting)
print(cfm)

print("Classification report:")
print(classification_report(y_test,y_pred_boosting))

accuracy_boosting=accuracy_score(y_test,y_pred_boosting)
print("Accuracy: {:.2f}%".format(accuracy_boosting * 100))
# Out:
# [[11  0  0  0  0  0]
#  [ 2 10  1  0  0  1]
#  [ 1  0  2  0  0  0]
#  [ 0  2  0  2  0  0]
#  [ 0  0  0  0  3  0]
#  [ 0  0  0  0  0  8]]
# Classification report:
#               precision    recall  f1-score   support
#
#            1       0.79      1.00      0.88        11
#            2       0.83      0.71      0.77        14
#            3       0.67      0.67      0.67         3
#            5       1.00      0.50      0.67         4
#            6       1.00      1.00      1.00         3
#            7       0.89      1.00      0.94         8
#
#     accuracy                           0.84        43
#    macro avg       0.86      0.81      0.82        43
# weighted avg       0.85      0.84      0.83        43
#
# Accuracy: 83.72%

# %%
#the accuracy for bagging and boosting is same(83.72%)
